# %%
from dotenv import load_dotenv
from langchain_groq import ChatGroq
import pandas
from rouge_score import rouge_scorer

load_dotenv("keys.env")

with open("context.txt",'r') as c:
    context = c.read()

messages = [(context),()]

scorer = rouge_scorer.RougeScorer(['rouge1'], use_stemmer=True)

llm = ChatGroq(
        model = "llama-3.3-70b-versatile",
        temperature=0,
        max_tokens=400
    )


train = pandas.read_parquet("validation-00000-of-00001.parquet")

# %%
#reference encounter data, candidate = note
average_precision = 0
for i in range(50):
    note = train["note"][i]

    messages[1] = note
    summary = llm.invoke(messages).content


    score = scorer.score(note,summary)
    precision = score['rouge1'][0]

    average_precision += precision

average_precision = average_precision/50

print(average_precision)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[43], line 7
#       4 note = train["note"][i]
#       6 messages[1] = note
# ----> 7 summary = llm.invoke(messages).content
#      10 score = scorer.score(note,summary)
#      11 precision = score['rouge1'][0]
#
# File d:\Clinical Note Summarizer\Lib\site-packages\langchain_core\language_models\chat_models.py:372, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     360 @override
#     361 def invoke(
#     362     self,
#    (...)    367     **kwargs: Any,
#     368 ) -> BaseMessage:
#     369     config = ensure_config(config)
#     370     return cast(
#     371         "ChatGeneration",
# --> 372         self.generate_prompt(
#     373             [self._convert_input(input)],
#     374             stop=stop,
#     375             callbacks=config.get("callbacks"),
# ...
